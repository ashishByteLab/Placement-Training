# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishByteLab/Placement-Training/blob/main/Placement_Training_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a,b=10,30
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# 30 10

# %%
  x=10
  y=7

  temp=x
  x=y
  y=temp
  print('Value of x after swapping: {}'.format(x))
  print('Value of y after swapping: {}'.format(y))
# Out:
# Value of x after swapping: 7
# Value of y after swapping: 10

# %%
x=100
y=7
x,y=y,x
print("x=",x)
print("y=",y)
# Out:
# x= 7
# y= 100

# %%
def candy()
    n = 10
    k = 5
    try:
        order = int(input())
        if order >= 1 and order <= n:
            sold = order
            available = n - order
            print(f"Number of Candies Sold: {sold}")
            print(f"Number of Candies available: {available}")
            if available <= k:
                available = n
        else:
            print("INVALID INPUT")
            print(f"Number of Candies available: {n}")
    except ValueError:
        print("INVALID INPUT")
        print(f"Number of Candies available: {n}")

if __name__ == "__main__":
    process_candy_order()
# Out:
#   File "/tmp/ipykernel_6867/1327842242.py", line 1
#     def candy()
#                ^
# SyntaxError: expected ':'

# %%
numbers = []
total = int(input("How many numbers do you want to enter? "))
for i in range(total):
    val = int(input(f"Enter number {i + 1}: "))
    numbers.append(val)
print("The smallest element is:", min(numbers))
# Out:
# How many numbers do you want to enter? 3
# Enter number 1: 24
# Enter number 2: 56
# Enter number 3: 8
# The smallest element is: 8

# %%
numbers = []
total = int(input("How many numbers do you want to enter? "))
for i in range(total):
    val = int(input(f"Enter number {i + 1}: "))
    numbers.append(val)
print("The smallest element is:", max(numbers))
4

# %%
numbers = []
total = int(input("How many numbers do you want to enter? "))
for i in range(total):
    val = int(input(f"Enter number {i + 1}: "))
    numbers.append(val)
print("The smallest element is:", sum(numbers))

# %%
numbers = []
total = int(input("How many numbers do you want to enter? "))
for i in range(total):
    val = int(input(f"Enter number {i + 1}: "))
    numbers.append(val)
print("Reverse array is:", numbers[::-1])
# Out:
# How many numbers do you want to enter? 4
# Enter number 1: 2
# Enter number 2: 3
# Enter number 3: 4
# Enter number 4: 5
# Reverse array is: [5, 4, 3, 2]

# %%
# Out:
#   File "/tmp/ipykernel_2654/71548175.py", line 5
#     numbers.append(val)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
numbers = []
total = int(input("How many numbers do you want to enter? "))
for i in range(total):
    val = int(input(f"Enter number {i + 1}: "))
    numbers.append(val)
print("Array entered is:", numbers[::1])
# Out:
# How many numbers do you want to enter? 4
# Enter number 1: 2
# Enter number 2: 3
# Enter number 3: 4
# Enter number 4: 5
# Array entered is: [2, 3, 4, 5]

# %%
numbers = []
total = int(input("How many numbers do you want to enter? "))
for i in range(total):
    val = int(input(f"Enter number {i + 1}: "))
    numbers.append(val)
search_val = int(input("Enter the number you want to find: "))
if search_val in numbers:
    print(f"{search_val} exists in the array.")
else:
    print(f"{search_val} does not exist in the array.")
# Out:
# How many numbers do you want to enter? 3
# Enter number 1: 2
# Enter number 2: 33
# Enter number 3: 5
# Enter the number you want to find: 33
# 33 exists in the array.

# %%
numbers = []
total = int(input("How many numbers do you want to enter? "))
for i in range(total):
    val = int(input(f"Enter number {i + 1}: "))
    numbers.append(val)
    unique_numbers = list(dict.fromkeys(numbers))
print("Array without duplicates:", unique_numbers)
# Out:
# How many numbers do you want to enter? 6
# Enter number 1: 22
# Enter number 2: 33
# Enter number 3: 56
# Enter number 4: 22
# Enter number 5: 67
# Enter number 6: 56
# Array without duplicates: [22, 33, 56, 67]

# %% [markdown]
# ### Sort the unique numbers
#
# Now that we have a list of unique numbers, let's sort them in ascending order.

# %%
arr=[]
n=int(input("Enter the number of list elements :"))
for i in range(n):
  a=input("Enter elements")
  arr.append(a)
  arr.sort()
print(arr)
# Out:
# Enter the number of list elements :5
# Enter elements2
# Enter elements3
# Enter elements6
# Enter elements
# Enter elements4
# ['', '2', '3', '4', '6']

# %%
n = int(input("Enter a number: "))
reversed_num = 0
while n > 0:
    reversed_num = (reversed_num * 10) + (n % 10)
    n = n // 10
print("Reversed number:", reversed_num)
# Out:
# Enter a number: 345
# Reversed number: 543

# %%
text = input("Enter a string: ")
reversed_text = text[::-1]
print("Reversed string:", reversed_text)
# Out:
# Enter a string: ashish
# Reversed string: hsihsa

# %%
n = input("Enter a number:")
sum_digits=sum(int(digit) for digit in n)
print("Sum of digits:", sum_digits)
# Out:
# Enter a number:2232
# Sum of digits: 9

# %%
text = input("Enter your text: ")
vowels = 0
consonants = 0
for char in text:
    if char in "aeiouAEIOU":
        vowels = vowels + 1
    elif char >= 'a' and char <= 'z':
        consonants = consonants + 1
    elif char >= 'A' and char <= 'Z':
        consonants = consonants + 1
print("Vowels:", vowels)
print("Consonants:", consonants)
# Out:
# Enter your text: Macbook Air
# Vowels: 5
# Consonants: 5
